# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_table('SMSSpamCollection', header=None,  names= ['label', 'text'])
df
# Out:
#      label                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df = pd.read_csv('SMSSpamCollection', sep='\t', names= ['label', 'text'])
df
# Out:
#      label                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.loc[7, 'text']
# Out:
# "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune"

# %% [markdown]
# Separate the input and output data

# %%
# Input
x = df['text']

# output
y = df['label']

# %%
sns.countplot(y)
y.value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
plt.pie(y.value_counts(), labels=y.value_counts().index, autopct='%2.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e9a36509d0>,
#   <matplotlib.patches.Wedge at 0x1e9a3650910>],
#  [Text(-1.0038714981945518, 0.4497132587689916, 'ham'),
#   Text(1.0038714771419537, -0.44971330576360763, 'spam')],
#  [Text(-0.5475662717424827, 0.24529814114672266, '86.59%'),
#   Text(0.5475662602592474, -0.2452981667801496, '13.41%')])

# %%
# !pip install pip -U
# Out:
# Requirement already satisfied: pip in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (23.3.1)
# Collecting pip
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\Administrator.DAI-PC2\.conda\envs\New\python.exe -m pip install pip -U

# %%
# !pip install pillow wordcloud -U
# Out:
# Requirement already satisfied: pillow in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (10.3.0)
# Requirement already satisfied: wordcloud in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from matplotlib->wordcloud) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator.dai-pc2\.conda\envs\new\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
x
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: text, Length: 5572, dtype: object

# %%
spam = df[df['label'] == 'spam']['text']
ham = df[df['label'] == 'ham']['text']

spam = x[y == 'spam']
ham = x[y == 'ham']

spam
# Out:
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 5       FreeMsg Hey there darling it's been 3 week's n...
# 8       WINNER!! As a valued network customer you have...
# 9       Had your mobile 11 months or more? U R entitle...
# 11      SIX chances to win CASH! From 100 to 20,000 po...
#                               ...
# 5537    Want explicit SEX in 30 secs? Ring 02073162414...
# 5540    ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...
# 5547    Had your contract mobile 11 Mnths? Latest Moto...
# 5566    REMINDER FROM O2: To get 2.50 pounds free call...
# 5567    This is the 2nd time we have tried 2 contact u...
# Name: text, Length: 747, dtype: object

# %%
# spam.str.cat(sep=' ')

# %%
spam = ' '.join(spam)
ham = ' '.join(ham)

# %%
from wordcloud import WordCloud

# %%
wc_ham = WordCloud(font_path='calibri.ttf',
               background_color='white', 
               max_words=100).generate(ham)

plt.figure(figsize=(8,6))
plt.imshow(wc_ham)

# %%
wc_spam = WordCloud(font_path='calibri.ttf',
               background_color='white', 
               max_words=100).generate(spam)

plt.figure(figsize=(8,6))
plt.imshow(wc_spam)

# %%
wc_spam.words_
# Out:
# {'FREE': 1.0,
#  'call': 0.875,
#  'text': 0.63,
#  'U': 0.59,
#  'txt': 0.5,
#  'now': 0.5,
#  'mobile': 0.5,
#  'won': 0.365,
#  'T C': 0.33,
#  'claim': 0.315,
#  'STOP': 0.315,
#  'reply': 0.31,
#  'prize': 0.305,
#  'call now': 0.29,
#  'URGENT': 0.28,
#  'win': 0.27,
#  'new': 0.27,
#  'tone': 0.265,
#  'co uk': 0.245,
#  '150p': 0.24,
#  'Please call': 0.23,
#  'will': 0.22,
#  'message': 0.21,
#  'chat': 0.2,
#  'ringtone': 0.18,
#  'cash': 0.17,
#  'receive': 0.165,
#  'send': 0.145,
#  'award': 0.14,
#  'want': 0.135,
#  'poly': 0.135,
#  'customer service': 0.135,
#  'PO Box': 0.135,
#  'contact U': 0.135,
#  'msg': 0.125,
#  'go': 0.125,
#  'SMS': 0.12,
#  'landline': 0.12,
#  '150ppm': 0.115,
#  'find': 0.115,
#  'collect': 0.115,
#  'phone': 0.115,
#  'GUARANTEED Call': 0.115,
#  'day': 0.11,
#  'uk': 0.11,
#  'offer': 0.11,
#  'chance': 0.11,
#  'prize GUARANTEED': 0.11,
#  'contact': 0.105,
#  'pic': 0.105,
#  'week': 0.1,
#  'customer': 0.1,
#  'send STOP': 0.1,
#  'national rate': 0.1,
#  'back': 0.095,
#  'ur': 0.095,
#  'awarded': 0.095,
#  'See': 0.095,
#  'Club': 0.095,
#  'Orange': 0.095,
#  'every week': 0.095,
#  'await collection': 0.095,
#  'PRIVATE': 0.09,
#  'Hi': 0.09,
#  'game': 0.09,
#  'land line': 0.09,
#  'selected': 0.085,
#  'latest': 0.085,
#  'tried': 0.085,
#  'Nokia': 0.085,
#  'end': 0.085,
#  'opt': 0.085,
#  'Valid 12hrs': 0.085,
#  'winner': 0.08,
#  'next': 0.08,
#  'know': 0.08,
#  'join': 0.08,
#  'Thank': 0.08,
#  'auction': 0.08,
#  'Free entry': 0.08,
#  'Account Statement': 0.08,
#  'Call Identifier': 0.08,
#  'Identifier Code': 0.08,
#  '150p msg': 0.08,
#  'Call MobileUpd8': 0.08,
#  'service': 0.075,
#  'trying': 0.075,
#  'sexy': 0.075,
#  'name': 0.075,
#  'number': 0.075,
#  'Xmas': 0.075,
#  '1st': 0.075,
#  'B': 0.075,
#  'draw shows': 0.075,
#  'ur mob': 0.075,
#  'Suite342 2Lands': 0.075,
#  '2Lands Row': 0.075,
#  'txt STOP': 0.075,
#  'dating service': 0.075,
#  'Update': 0.07}

# %%
wc_ham.words_
# Out:
# {'u': 1.0,
#  'will': 0.33096446700507615,
#  'lt gt': 0.2802030456852792,
#  'Ok': 0.2649746192893401,
#  'now': 0.2578680203045685,
#  'go': 0.25583756345177666,
#  'got': 0.2365482233502538,
#  'know': 0.2182741116751269,
#  'come': 0.21116751269035533,
#  'call': 0.20812182741116753,
#  'love': 0.20609137055837565,
#  'time': 0.20101522842639594,
#  'ur': 0.19898477157360406,
#  'day': 0.18883248730964466,
#  'want': 0.18781725888324874,
#  'one': 0.17766497461928935,
#  'need': 0.17563451776649747,
#  'going': 0.1715736040609137,
#  'good': 0.166497461928934,
#  'Sorry': 0.15939086294416244,
#  'ü': 0.15634517766497463,
#  'home': 0.15532994923857868,
#  'still': 0.1532994923857868,
#  'da': 0.14416243654822336,
#  'see': 0.14213197969543148,
#  'today': 0.1401015228426396,
#  'think': 0.13401015228426397,
#  'n': 0.132994923857868,
#  'lor': 0.12791878172588833,
#  'tell': 0.12690355329949238,
#  'dont': 0.12284263959390863,
#  'say': 0.12081218274111676,
#  'back': 0.12081218274111676,
#  'Oh': 0.11573604060913706,
#  'thing': 0.11472081218274112,
#  'much': 0.11370558375634518,
#  'hope': 0.11269035532994924,
#  'well': 0.11065989847715736,
#  'Hey': 0.10862944162436548,
#  'send': 0.1065989847715736,
#  'work': 0.10558375634517767,
#  'make': 0.10456852791878173,
#  'way': 0.10253807106598985,
#  'give': 0.10253807106598985,
#  'take': 0.10152284263959391,
#  'dear': 0.10050761421319797,
#  'let': 0.09340101522842639,
#  'ask': 0.09238578680203045,
#  'already': 0.09137055837563451,
#  'Thank': 0.09137055837563451,
#  'later': 0.09035532994923857,
#  'wat': 0.08934010152284264,
#  'Yeah': 0.08730964467005076,
#  'really': 0.08629441624365482,
#  'e': 0.08527918781725888,
#  'd': 0.08527918781725888,
#  'great': 0.08426395939086294,
#  'said': 0.08223350253807106,
#  'life': 0.08223350253807106,
#  'co': 0.07918781725888324,
#  'Yes': 0.07817258883248732,
#  'text': 0.07817258883248732,
#  'friend': 0.07817258883248732,
#  'Hi': 0.07715736040609138,
#  'night': 0.07715736040609138,
#  'babe': 0.07614213197969544,
#  'im': 0.07614213197969544,
#  'Lol': 0.0751269035532995,
#  'amp': 0.07411167512690356,
#  'meet': 0.07208121827411168,
#  'please': 0.07208121827411168,
#  'number': 0.07208121827411168,
#  'tomorrow': 0.07106598984771574,
#  'miss': 0.07106598984771574,
#  'phone': 0.07106598984771574,
#  'something': 0.0700507614213198,
#  'message': 0.0700507614213198,
#  'anything': 0.06802030456852792,
#  'feel': 0.06700507614213198,
#  'Happy': 0.06700507614213198,
#  'keep': 0.06700507614213198,
#  's': 0.06598984771573604,
#  'leave': 0.06598984771573604,
#  'sure': 0.06294416243654823,
#  'buy': 0.06294416243654823,
#  'went': 0.06294416243654823,
#  'b': 0.06192893401015229,
#  'around': 0.05989847715736041,
#  'msg': 0.05989847715736041,
#  'even': 0.05888324873096447,
#  'gonna': 0.05888324873096447,
#  'always': 0.05888324873096447,
#  'late': 0.05888324873096447,
#  'pick': 0.05786802030456853,
#  'free': 0.05786802030456853,
#  'guy': 0.05786802030456853,
#  'money': 0.05685279187817259,
#  'sent': 0.05583756345177665,
#  'lot': 0.05482233502538071,
#  'told': 0.05482233502538071}

# %% [markdown]
# Data Preparation

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
sent = 'Hello friends! How are you? I like Python Programming.'

# %%
# 1. Tokenize
tokens1 = word_tokenize(sent)
tokens1
# Out:
# ['Hello',
#  'friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'I',
#  'like',
#  'Python',
#  'Programming',
#  '.']

# %%
# 2. Remove the punctuations
tokens2 = [token for token in tokens1 if token.isalnum()]
tokens2
# Out:
# ['Hello', 'friends', 'How', 'are', 'you', 'I', 'like', 'Python', 'Programming']

# %%
# 3. Remove stopwords
swords = stopwords.words('english')

tokens3 = [token for token in tokens2 if token.lower() not in swords]
tokens3
# Out:
# ['Hello', 'friends', 'like', 'Python', 'Programming']

# %%
# 4. Remove the suffixes from text
ps = PorterStemmer()
tokens4 = [ps.stem(token) for token in tokens3]
tokens4
# Out:
# ['hello', 'friend', 'like', 'python', 'program']

# %%
# Function for cleaning the data
def clean_text(text):
    ps = PorterStemmer()
    tokens1 = word_tokenize(text)
    tokens2 = [token for token in tokens1 if token.isalnum()]
    swords = stopwords.words('english')
    tokens3 = [token for token in tokens2 if token.lower() not in swords]
    tokens4 = [ps.stem(token) for token in tokens3]
    return tokens4

# %%
# def clean_text(text):
#     return

# %%
clean_text(sent)
# Out:
# ['hello', 'friend', 'like', 'python', 'program']

# %%
sent1 = 'It was the expected result on that occasion.'

# %%
clean_text(sent1)
# Out:
# ['expect', 'result', 'occas']

# %%
x.loc[400]
# Out:
# 'Hmmm...k...but i want to change the field quickly da:-)i wanna get system administrator or network administrator..'

# %%
clean_text(x.loc[400])
# Out:
# ['hmmm',
#  'k',
#  'want',
#  'chang',
#  'field',
#  'quickli',
#  'da',
#  'wan',
#  'na',
#  'get',
#  'system',
#  'administr',
#  'network',
#  'administr']

# %%
# cleaned_text = x.apply(lambda x: clean_text(x))
# cleaned_text

# %%
cleaned_text = x.apply(clean_text)
cleaned_text
# Out:
# 0       [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                            [ok, lar, joke, wif, u, oni]
# 2       [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3           [u, dun, say, earli, hor, u, c, alreadi, say]
# 4            [nah, think, goe, usf, live, around, though]
#                               ...
# 5567    [2nd, time, tri, 2, contact, u, pound, prize, ...
# 5568                       [ü, b, go, esplanad, fr, home]
# 5569                                [piti, mood, suggest]
# 5570    [guy, bitch, act, like, interest, buy, someth,...
# 5571                                   [rofl, true, name]
# Name: text, Length: 5572, dtype: object

# %%
# clean_text(' '.join(x))

# %%
# ' '.join(cleaned_text)

# %% [markdown]
# TF*IDF Vectorizer

# %%
# import the class
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# create the object
tfidf = TfidfVectorizer(analyzer=clean_text)

# %%
# apply
x_new = tfidf.fit_transform(x)
x_new
# Out:
# <5572x6854 sparse matrix of type '<class 'numpy.float64'>'
# 	with 47556 stored elements in Compressed Sparse Row format>

# %%
x_new.data
# Out:
# array([0.18656776, 0.33773999, 0.1565674 , ..., 0.69486698, 0.53382625,
#        0.48186037])

# %% [markdown]
# Cross_Validation

# %%
# Import the function
from sklearn.model_selection import train_test_split

# %%
# seperate the training and testing
X_train, X_test, y_train, y_test = train_test_split(x_new, y, 
                                                    random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (4179, 6854)
# (1393, 6854)

# %%
tfidf.get_feature_names_out()
# Out:
# array(['0', '008704050406', '0089', ..., 'é', 'ü', '〨ud'], dtype=object)

# %% [markdown]
# Build the machine learning classification model

# %%
# Import the class
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, r2_score, log_loss, confusion_matrix, ConfusionMatrixDisplay

# %%
# Create the object
svm = SVC(kernel='linear', random_state=0)

# %%
import time

# %%
# %%time
svm.fit(X_train, y_train)
# Out:
# CPU times: total: 500 ms
# Wall time: 517 ms
# SVC(kernel='linear', random_state=0)

# %%
y_pred = svm.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99      1208
#         spam       0.99      0.88      0.93       185
#
#     accuracy                           0.98      1393
#    macro avg       0.99      0.94      0.96      1393
# weighted avg       0.98      0.98      0.98      1393

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1207,    1],
#        [  22,  163]], dtype=int64)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9834888729361091

# %% [markdown]
# RBF -> 0.9798994974874372 \
# Linear -> 0.9834888729361091 \
# Poly -> 0.9361091170136396 \
# Sigmoid -> 0.9806173725771715

# %% [markdown]
# Predictions on Unseen Data

# %%
val = open('sample.csv','r')
val_data = val.readlines()

# %%
val_data
# Out:
# ['Ok lar i double check wif da hair dresser already he said wun cut v short. He said will cut until i look nice.,,\n',
#  'As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a £1500 Bonus Prize, call 09066364589\n',
#  '"Today is ""song dedicated day.."" Which song will u dedicate for me? Send this to all ur valuable frnds but first rply me...",,\n']

# %%
val = val_data
val
# Out:
# ['Ok lar i double check wif da hair dresser already he said wun cut v short. He said will cut until i look nice.,,\n',
#  'As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a £1500 Bonus Prize, call 09066364589\n',
#  '"Today is ""song dedicated day.."" Which song will u dedicate for me? Send this to all ur valuable frnds but first rply me...",,\n']

# %%
# apply
val_new = tfidf.transform(val)

val_new.data
# Out:
# array([0.26612968, 0.22323168, 0.20764979, 0.25489893, 0.36897495,
#        0.1430883 , 0.18864127, 0.21117938, 0.23045406, 0.29057455,
#        0.23381532, 0.16647245, 0.49278798, 0.19750425, 0.18077178,
#        0.28852885, 0.32898788, 0.30962565, 0.22103571, 0.20221403,
#        0.27277618, 0.29633917, 0.23486274, 0.13896166, 0.27993247,
#        0.23767281, 0.34340174, 0.36528459, 0.30072906, 0.14183103,
#        0.10653404, 0.16302733, 0.50497278, 0.15776238, 0.26063089,
#        0.22842463, 0.20188813, 0.6224583 , 0.15268491])

# %%
y_pred_val = svm.predict(val_new)

y_pred_val
# Out:
# array(['ham', 'spam', 'ham'], dtype=object)

# %% [markdown]
# Serialize the objects

# %%
import joblib

# %%
joblib.dump(svm, 'classifier.model')
# Out:
# ['classifier.model']

# %%
joblib.dump(tfidf, 'preprocessor.model')
# Out:
# ['preprocessor.model']
