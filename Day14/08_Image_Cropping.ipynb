# %%
import cv2
import matplotlib.pyplot as plt

# load the image
image = cv2.imread('../images/lenna.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# show image
plt.imshow(image)

# show image not working for cdac pc 19 (aka chhota param)
# cv2.imshow('Original', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
image.shape
# Out:
# (512, 512, 3)

# %%
512*0.15
# Out:
# 76.8

# %%
77
# Out:
# 77

# %%
512*0.85
# Out:
# 435.2

# %%
height, width, channels = image.shape

# %%
start_row = int(height * .15)
start_col = int(width  * .15)
end_row = int(height * .85)
end_col = int(width  * .85)

# %%
cropped = image[start_row: end_row, start_col: end_col]

# %%
plt.imshow(cropped)

# %% [markdown]
# Wanted image of size 150x200 starting from (100,125)

# %%
cropped = image[100:100+150, 125:125+200]
plt.imshow(cropped)

# %% [markdown]
# Cropping with PIL

# %%
from PIL import Image

# %%
image = Image.open('../images/lenna.png')

# %%
image.crop((100, 100, 400, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
