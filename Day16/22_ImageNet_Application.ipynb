# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.models import Sequential
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Build Model

# %%
def build_CNN(input_shape= (224, 224, 3), num_classes= 10):
    model = Sequential()

    model.add(Conv2D(filters= 32, kernel_size= (3, 3),
                 activation='relu', input_shape=input_shape))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(filters= 64, kernel_size= (3, 3),
                 activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(10, activation='softmax'))
    
    return model

# %%
model = build_CNN(input_shape=(64, 64, 3))
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 10)                125450
#
# =================================================================
# Total params: 144842 (565.79 KB)
# Trainable params: 144842 (565.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Clean the iMage Data Generator

# %%
train_datagen = ImageDataGenerator(rescale= 1/ 255,
                                   shear_range= 0.2,
                                   zoom_range= 0.2, 
                                   horizontal_flip= True)

# %%
test_datagen = ImageDataGenerator(rescale= 1/ 255)

# %%
train_dataset = train_datagen.flow_from_directory('../Dataset/imagenet/train/', 
                                                  target_size= (64,64), 
                                                  batch_size= 32, 
                                                  class_mode= 'categorical')
# Out:
# Found 5000 images belonging to 10 classes.

# %%
test_dataset = test_datagen.flow_from_directory('../Dataset/imagenet/test/', 
                                                  target_size= (64,64), 
                                                  batch_size= 32, 
                                                  class_mode= 'categorical')
# Out:
# Found 10000 images belonging to 1 classes.

# %%
train_dataset.class_indices
# Out:
# {'crocodile': 0,
#  'fish': 1,
#  'fossils': 2,
#  'frog': 3,
#  'insect': 4,
#  'reptiles': 5,
#  'scorpion': 6,
#  'snake': 7,
#  'spider': 8,
#  'toad': 9}

# %% [markdown]
# Compile MOdel

# %%
model.compile(loss= 'categorical_crossentropy', 
              optimizer= 'adam', metrics= ['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# Train MOdel

# %%
model.fit(train_dataset, epochs= 10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 157/157 [==============================] - 60s 375ms/step - loss: 2.0057 - accuracy: 0.2816
# Epoch 2/10
# 157/157 [==============================] - 53s 335ms/step - loss: 1.7043 - accuracy: 0.4076
# Epoch 3/10
# 157/157 [==============================] - 47s 302ms/step - loss: 1.6081 - accuracy: 0.4534
# Epoch 4/10
# 157/157 [==============================] - 79s 505ms/step - loss: 1.4953 - accuracy: 0.4902
# Epoch 5/10
# 157/157 [==============================] - 125s 792ms/step - loss: 1.4499 - accuracy: 0.5016
# Epoch 6/10
# 157/157 [==============================] - 80s 506ms/step - loss: 1.3705 - accuracy: 0.5356
# Epoch 7/10
# 157/157 [==============================] - 52s 333ms/step - loss: 1.3043 - accuracy: 0.5580
# Epoch 8/10
# 157/157 [==============================] - 44s 280ms/step - loss: 1.2646 - accuracy: 0.5730
# Epoch 9/10
# 157/157 [==============================] - 52s 328ms/step - loss: 1.2204 - accuracy: 0.5850
# Epoch 10/10
# 157/157 [==============================] - 51s 325ms/step - loss: 1.1660 - accuracy: 0.6096

# %%
import os

# %%
lst = []
lst = os.listdir('../Dataset/imagenet/test/images')

lst
# Out:
# ['test_2289.JPEG',
#  'test_6403.JPEG',
#  'test_3182.JPEG',
#  'test_5646.JPEG',
#  'test_3339.JPEG',
#  'test_8902.JPEG',
#  'test_1364.JPEG',
#  'test_574.JPEG',
#  'test_765.JPEG',
#  'test_6401.JPEG',
#  'test_5794.JPEG',
#  'test_9681.JPEG',
#  'test_9296.JPEG',
#  'test_2893.JPEG',
#  'test_7917.JPEG',
#  'test_9415.JPEG',
#  'test_6023.JPEG',
#  'test_3492.JPEG',
#  'test_930.JPEG',
#  'test_7476.JPEG',
#  'test_8829.JPEG',
#  'test_6178.JPEG',
#  'test_9685.JPEG',
#  'test_4530.JPEG',
#  'test_5356.JPEG',
#  'test_3727.JPEG',
#  'test_6056.JPEG',
#  'test_9520.JPEG',
#  'test_8318.JPEG',
#  'test_3737.JPEG',
#  'test_5571.JPEG',
#  'test_6653.JPEG',
#  'test_7117.JPEG',
#  'test_1268.JPEG',
#  'test_6765.JPEG',
#  'test_6628.JPEG',
#  'test_5899.JPEG',
#  'test_4665.JPEG',
#  'test_5734.JPEG',
#  'test_1440.JPEG',
#  'test_6062.JPEG',
#  'test_6690.JPEG',
#  'test_8263.JPEG',
#  'test_8451.JPEG',
#  'test_898.JPEG',
#  'test_3742.JPEG',
#  'test_8368.JPEG',
#  'test_347.JPEG',
#  'test_3680.JPEG',
#  'test_4054.JPEG',
#  'test_1259.JPEG',
#  'test_2294.JPEG',
#  'test_6219.JPEG',
#  'test_6279.JPEG',
#  'test_2144.JPEG',
#  'test_303.JPEG',
#  'test_7905.JPEG',
#  'test_9698.JPEG',
#  'test_1415.JPEG',
#  'test_3193.JPEG',
#  'test_6696.JPEG',
#  'test_8492.JPEG',
#  'test_9568.JPEG',
#  'test_4889.JPEG',
#  'test_8213.JPEG',
#  'test_9448.JPEG',
#  'test_9245.JPEG',
#  'test_8077.JPEG',
#  'test_4314.JPEG',
#  'test_8971.JPEG',
#  'test_460.JPEG',
#  'test_6884.JPEG',
#  'test_5515.JPEG',
#  'test_5533.JPEG',
#  'test_25.JPEG',
#  'test_8793.JPEG',
#  'test_575.JPEG',
#  'test_555.JPEG',
#  'test_1835.JPEG',
#  'test_2960.JPEG',
#  'test_659.JPEG',
#  'test_8310.JPEG',
#  'test_698.JPEG',
#  'test_69.JPEG',
#  'test_6232.JPEG',
#  'test_2552.JPEG',
#  'test_6436.JPEG',
#  'test_3919.JPEG',
#  'test_5584.JPEG',
#  'test_4808.JPEG',
#  'test_1820.JPEG',
#  'test_2409.JPEG',
#  'test_286.JPEG',
#  'test_6885.JPEG',
#  'test_6215.JPEG',
#  'test_3754.JPEG',
#  'test_9826.JPEG',
#  'test_3163.JPEG',
#  'test_6996.JPEG',
#  'test_8680.JPEG',
#  'test_3969.JPEG',
#  'test_4369.JPEG',
#  'test_6731.JPEG',
#  'test_4053.JPEG',
#  'test_7058.JPEG',
#  'test_7447.JPEG',
#  'test_3811.JPEG',
#  'test_4026.JPEG',
#  'test_959.JPEG',
#  'test_9054.JPEG',
#  'test_2001.JPEG',
#  'test_6031.JPEG',
#  'test_5484.JPEG',
#  'test_1883.JPEG',
#  'test_8473.JPEG',
#  'test_9372.JPEG',
#  'test_3965.JPEG',
#  'test_1032.JPEG',
#  'test_1701.JPEG',
#  'test_5405.JPEG',
#  'test_1207.JPEG',
#  'test_1384.JPEG',
#  'test_4874.JPEG',
#  'test_7799.JPEG',
#  'test_5425.JPEG',
#  'test_3675.JPEG',
#  'test_6618.JPEG',
#  'test_4075.JPEG',
#  'test_8724.JPEG',
#  'test_6307.JPEG',
#  'test_481.JPEG',
#  'test_4739.JPEG',
#  'test_5842.JPEG',
#  'test_2084.JPEG',
#  'test_410.JPEG',
#  'test_8307.JPEG',
#  'test_7031.JPEG',
#  'test_6338.JPEG',
#  'test_5221.JPEG',
#  'test_6262.JPEG',
#  'test_7118.JPEG',
#  'test_1656.JPEG',
#  'test_4190.JPEG',
#  'test_9653.JPEG',
#  'test_2272.JPEG',
#  'test_1438.JPEG',
#  'test_6346.JPEG',
#  'test_96.JPEG',
#  'test_7166.JPEG',
#  'test_140.JPEG',
#  'test_1433.JPEG',
#  'test_7939.JPEG',
#  'test_4702.JPEG',
#  'test_3242.JPEG',
#  'test_4502.JPEG',
#  'test_7609.JPEG',
#  'test_2567.JPEG',
#  'test_949.JPEG',
#  'test_1753.JPEG',
#  'test_9.JPEG',
#  'test_2215.JPEG',
#  'test_7252.JPEG',
#  'test_4780.JPEG',
#  'test_8604.JPEG',
#  'test_1465.JPEG',
#  'test_5527.JPEG',
#  'test_6557.JPEG',
#  'test_3617.JPEG',
#  'test_7061.JPEG',
#  'test_4032.JPEG',
#  'test_8962.JPEG',
#  'test_7504.JPEG',
#  'test_7676.JPEG',
#  'test_1998.JPEG',
#  'test_1839.JPEG',
#  'test_230.JPEG',
#  'test_8859.JPEG',
#  'test_9597.JPEG',
#  'test_5943.JPEG',
#  'test_6519.JPEG',
#  'test_3332.JPEG',
#  'test_8022.JPEG',
#  'test_1161.JPEG',
#  'test_8875.JPEG',
#  'test_3693.JPEG',
#  'test_6402.JPEG',
#  'test_9374.JPEG',
#  'test_1808.JPEG',
#  'test_940.JPEG',
#  'test_8405.JPEG',
#  'test_8932.JPEG',
#  'test_5344.JPEG',
#  'test_1453.JPEG',
#  'test_9782.JPEG',
#  'test_1961.JPEG',
#  'test_2669.JPEG',
#  'test_8978.JPEG',
#  'test_4685.JPEG',
#  'test_4381.JPEG',
#  'test_4068.JPEG',
#  'test_8760.JPEG',
#  'test_7553.JPEG',
#  'test_6176.JPEG',
#  'test_1336.JPEG',
#  'test_3035.JPEG',
#  'test_1192.JPEG',
#  'test_2458.JPEG',
#  'test_8588.JPEG',
#  'test_5394.JPEG',
#  'test_8527.JPEG',
#  'test_2269.JPEG',
#  'test_4435.JPEG',
#  'test_7088.JPEG',
#  'test_5508.JPEG',
#  'test_9078.JPEG',
#  'test_9992.JPEG',
#  'test_5473.JPEG',
#  'test_6538.JPEG',
#  'test_7938.JPEG',
#  'test_3729.JPEG',
#  'test_8776.JPEG',
#  'test_8825.JPEG',
#  'test_2536.JPEG',
#  'test_1733.JPEG',
#  'test_871.JPEG',
#  'test_1386.JPEG',
#  'test_5582.JPEG',
#  'test_2885.JPEG',
#  'test_4264.JPEG',
#  'test_1595.JPEG',
#  'test_2090.JPEG',
#  'test_48.JPEG',
#  'test_5075.JPEG',
#  'test_521.JPEG',
#  'test_1489.JPEG',
#  'test_7771.JPEG',
#  'test_7701.JPEG',
#  'test_1729.JPEG',
#  'test_5564.JPEG',
#  'test_6572.JPEG',
#  'test_3005.JPEG',
#  'test_1564.JPEG',
#  'test_8055.JPEG',
#  'test_7777.JPEG',
#  'test_5313.JPEG',
#  'test_5567.JPEG',
#  'test_7415.JPEG',
#  'test_9989.JPEG',
#  'test_4897.JPEG',
#  'test_1308.JPEG',
#  'test_4924.JPEG',
#  'test_406.JPEG',
#  'test_2040.JPEG',
#  'test_5115.JPEG',
#  'test_6971.JPEG',
#  'test_9815.JPEG',
#  'test_4732.JPEG',
#  'test_6789.JPEG',
#  'test_8226.JPEG',
#  'test_1397.JPEG',
#  'test_8692.JPEG',
#  'test_7344.JPEG',
#  'test_2563.JPEG',
#  'test_4282.JPEG',
#  'test_1052.JPEG',
#  'test_3862.JPEG',
#  'test_8615.JPEG',
#  'test_3521.JPEG',
#  'test_1910.JPEG',
#  'test_1731.JPEG',
#  'test_3122.JPEG',
#  'test_1536.JPEG',
#  'test_499.JPEG',
#  'test_8164.JPEG',
#  'test_6670.JPEG',
#  'test_5557.JPEG',
#  'test_817.JPEG',
#  'test_4825.JPEG',
#  'test_1799.JPEG',
#  'test_7652.JPEG',
#  'test_8048.JPEG',
#  'test_4255.JPEG',
#  'test_7500.JPEG',
#  'test_9072.JPEG',
#  'test_9796.JPEG',
#  'test_4631.JPEG',
#  'test_3170.JPEG',
#  'test_8165.JPEG',
#  'test_4675.JPEG',
#  'test_805.JPEG',
#  'test_1017.JPEG',
#  'test_4875.JPEG',
#  'test_4365.JPEG',
#  'test_6145.JPEG',
#  'test_2929.JPEG',
#  'test_5372.JPEG',
#  'test_7238.JPEG',
#  'test_789.JPEG',
#  'test_4450.JPEG',
#  'test_9507.JPEG',
#  'test_9585.JPEG',
#  'test_5471.JPEG',
#  'test_9236.JPEG',
#  'test_3768.JPEG',
#  'test_3293.JPEG',
#  'test_8824.JPEG',
#  'test_9439.JPEG',
#  'test_1020.JPEG',
#  'test_5965.JPEG',
#  'test_6878.JPEG',
#  'test_730.JPEG',
#  'test_7603.JPEG',
#  'test_4367.JPEG',
#  'test_9618.JPEG',
#  'test_9804.JPEG',
#  'test_5979.JPEG',
#  'test_3268.JPEG',
#  'test_3154.JPEG',
#  'test_9603.JPEG',
#  'test_9162.JPEG',
#  'test_247.JPEG',
#  'test_6837.JPEG',
#  'test_1786.JPEG',
#  'test_4438.JPEG',
#  'test_2818.JPEG',
#  'test_2430.JPEG',
#  'test_5825.JPEG',
#  'test_9425.JPEG',
#  'test_2043.JPEG',
#  'test_4386.JPEG',
#  'test_4604.JPEG',
#  'test_3739.JPEG',
#  'test_7996.JPEG',
#  'test_5707.JPEG',
#  'test_6458.JPEG',
#  'test_7027.JPEG',
#  'test_3364.JPEG',
#  'test_1194.JPEG',
#  'test_2799.JPEG',
#  'test_654.JPEG',
#  'test_9607.JPEG',
#  'test_8060.JPEG',
#  'test_1928.JPEG',
#  'test_428.JPEG',
#  'test_7576.JPEG',
#  'test_7932.JPEG',
#  'test_9059.JPEG',
#  'test_8326.JPEG',
#  'test_8535.JPEG',
#  'test_8418.JPEG',
#  'test_2191.JPEG',
#  'test_7883.JPEG',
#  'test_7773.JPEG',
#  'test_4018.JPEG',
#  'test_2980.JPEG',
#  'test_1513.JPEG',
#  'test_6701.JPEG',
#  'test_5031.JPEG',
#  'test_494.JPEG',
#  'test_8312.JPEG',
#  'test_1780.JPEG',
#  'test_2743.JPEG',
#  'test_2064.JPEG',
#  'test_7310.JPEG',
#  'test_2749.JPEG',
#  'test_9692.JPEG',
#  'test_7295.JPEG',
#  'test_4657.JPEG',
#  'test_771.JPEG',
#  'test_9488.JPEG',
#  'test_5251.JPEG',
#  'test_4047.JPEG',
#  'test_2109.JPEG',
#  'test_1635.JPEG',
#  'test_5592.JPEG',
#  'test_2545.JPEG',
#  'test_3894.JPEG',
#  'test_7010.JPEG',
#  'test_3099.JPEG',
#  'test_8250.JPEG',
#  'test_2450.JPEG',
#  'test_6203.JPEG',
#  'test_7242.JPEG',
#  'test_75.JPEG',
#  'test_7471.JPEG',
#  'test_1217.JPEG',
#  'test_6987.JPEG',
#  'test_3152.JPEG',
#  'test_8747.JPEG',
#  'test_9248.JPEG',
#  'test_2247.JPEG',
#  'test_1326.JPEG',
#  'test_4447.JPEG',
#  'test_945.JPEG',
#  'test_4427.JPEG',
#  'test_9313.JPEG',
#  'test_1901.JPEG',
#  'test_6737.JPEG',
#  'test_1173.JPEG',
#  'test_2712.JPEG',
#  'test_7351.JPEG',
#  'test_357.JPEG',
#  'test_6610.JPEG',
#  'test_4137.JPEG',
#  'test_2060.JPEG',
#  'test_7263.JPEG',
#  'test_8369.JPEG',
#  'test_6034.JPEG',
#  'test_8005.JPEG',
#  'test_1085.JPEG',
#  'test_7593.JPEG',
#  'test_9262.JPEG',
#  'test_1483.JPEG',
#  'test_5384.JPEG',
#  'test_4205.JPEG',
#  'test_7786.JPEG',
#  'test_8924.JPEG',
#  'test_582.JPEG',
#  'test_9929.JPEG',
#  'test_6668.JPEG',
#  'test_1158.JPEG',
#  'test_3574.JPEG',
#  'test_5049.JPEG',
#  'test_2746.JPEG',
#  'test_4355.JPEG',
#  'test_8942.JPEG',
#  'test_14.JPEG',
#  'test_5555.JPEG',
#  'test_1086.JPEG',
#  'test_2758.JPEG',
#  'test_7781.JPEG',
#  'test_4189.JPEG',
#  'test_9671.JPEG',
#  'test_4506.JPEG',
#  'test_5183.JPEG',
#  'test_6295.JPEG',
#  'test_5702.JPEG',
#  'test_3148.JPEG',
#  'test_6727.JPEG',
#  'test_6568.JPEG',
#  'test_7964.JPEG',
#  'test_3470.JPEG',
#  'test_5799.JPEG',
#  'test_8719.JPEG',
#  'test_3738.JPEG',
#  'test_9981.JPEG',
#  'test_9855.JPEG',
#  'test_6684.JPEG',
#  'test_790.JPEG',
#  'test_9821.JPEG',
#  'test_4828.JPEG',
#  'test_6613.JPEG',
#  'test_955.JPEG',
#  'test_6749.JPEG',
#  'test_9961.JPEG',
#  'test_5732.JPEG',
#  'test_7674.JPEG',
#  'test_7687.JPEG',
#  'test_489.JPEG',
#  'test_4171.JPEG',
#  'test_3914.JPEG',
#  'test_7406.JPEG',
#  'test_5006.JPEG',
#  'test_8509.JPEG',
#  'test_7739.JPEG',
#  'test_8873.JPEG',
#  'test_8907.JPEG',
#  'test_9859.JPEG',
#  'test_9750.JPEG',
#  'test_1978.JPEG',
#  'test_9117.JPEG',
#  'test_4483.JPEG',
#  'test_5543.JPEG',
#  'test_1423.JPEG',
#  'test_8532.JPEG',
#  'test_9817.JPEG',
#  'test_5030.JPEG',
#  'test_8193.JPEG',
#  'test_8475.JPEG',
#  'test_245.JPEG',
#  'test_2724.JPEG',
#  'test_7084.JPEG',
#  'test_3808.JPEG',
#  'test_5036.JPEG',
#  'test_7790.JPEG',
#  'test_2315.JPEG',
#  'test_2372.JPEG',
#  'test_4649.JPEG',
#  'test_3379.JPEG',
#  'test_8502.JPEG',
#  'test_830.JPEG',
#  'test_2634.JPEG',
#  'test_9058.JPEG',
#  'test_2140.JPEG',
#  'test_8233.JPEG',
#  'test_5143.JPEG',
#  'test_5501.JPEG',
#  'test_9595.JPEG',
#  'test_4306.JPEG',
#  'test_9071.JPEG',
#  'test_3402.JPEG',
#  'test_1335.JPEG',
#  'test_8240.JPEG',
#  'test_5022.JPEG',
#  'test_3064.JPEG',
#  'test_3926.JPEG',
#  'test_5029.JPEG',
#  'test_6759.JPEG',
#  'test_5220.JPEG',
#  'test_253.JPEG',
#  'test_2663.JPEG',
#  'test_8941.JPEG',
#  'test_2979.JPEG',
#  'test_972.JPEG',
#  'test_3813.JPEG',
#  'test_487.JPEG',
#  'test_9053.JPEG',
#  'test_6773.JPEG',
#  'test_5603.JPEG',
#  'test_7343.JPEG',
#  'test_1895.JPEG',
#  'test_5292.JPEG',
#  'test_4114.JPEG',
#  'test_9923.JPEG',
#  'test_28.JPEG',
#  'test_7333.JPEG',
#  'test_6741.JPEG',
#  'test_1229.JPEG',
#  'test_5316.JPEG',
#  'test_2270.JPEG',
#  'test_4917.JPEG',
#  'test_29.JPEG',
#  'test_7440.JPEG',
#  'test_8220.JPEG',
#  'test_8545.JPEG',
#  'test_480.JPEG',
#  'test_4972.JPEG',
#  'test_8334.JPEG',
#  'test_1114.JPEG',
#  'test_4826.JPEG',
#  'test_6708.JPEG',
#  'test_6495.JPEG',
#  'test_3646.JPEG',
#  'test_7873.JPEG',
#  'test_1479.JPEG',
#  'test_5706.JPEG',
#  'test_5371.JPEG',
#  'test_59.JPEG',
#  'test_9441.JPEG',
#  'test_5875.JPEG',
#  'test_8448.JPEG',
#  'test_8961.JPEG',
#  'test_4110.JPEG',
#  'test_2455.JPEG',
#  'test_458.JPEG',
#  'test_6130.JPEG',
#  'test_6661.JPEG',
#  'test_7056.JPEG',
#  'test_6227.JPEG',
#  'test_6923.JPEG',
#  'test_716.JPEG',
#  'test_2008.JPEG',
#  'test_7074.JPEG',
#  'test_4566.JPEG',
#  'test_7224.JPEG',
#  'test_5594.JPEG',
#  'test_9481.JPEG',
#  'test_6472.JPEG',
#  'test_3169.JPEG',
#  'test_2531.JPEG',
#  'test_1193.JPEG',
#  'test_5673.JPEG',
#  'test_6410.JPEG',
#  'test_8034.JPEG',
#  'test_4437.JPEG',
#  'test_7878.JPEG',
#  'test_9065.JPEG',
#  'test_2879.JPEG',
#  'test_1311.JPEG',
#  'test_9549.JPEG',
#  'test_3274.JPEG',
#  'test_1793.JPEG',
#  'test_8718.JPEG',
#  'test_5827.JPEG',
#  'test_3393.JPEG',
#  'test_9339.JPEG',
#  'test_8786.JPEG',
#  'test_5685.JPEG',
#  'test_2401.JPEG',
#  'test_8054.JPEG',
#  'test_604.JPEG',
#  'test_3842.JPEG',
#  'test_9252.JPEG',
#  'test_5459.JPEG',
#  'test_2695.JPEG',
#  'test_1115.JPEG',
#  'test_7911.JPEG',
#  'test_1931.JPEG',
#  'test_3974.JPEG',
#  'test_1398.JPEG',
#  'test_1257.JPEG',
#  'test_8017.JPEG',
#  'test_2350.JPEG',
#  'test_7153.JPEG',
#  'test_8542.JPEG',
#  'test_6322.JPEG',
#  'test_9340.JPEG',
#  'test_5795.JPEG',
#  'test_156.JPEG',
#  'test_672.JPEG',
#  'test_9866.JPEG',
#  'test_2661.JPEG',
#  'test_5669.JPEG',
#  'test_181.JPEG',
#  'test_1092.JPEG',
#  'test_3735.JPEG',
#  'test_4726.JPEG',
#  'test_3410.JPEG',
#  'test_5133.JPEG',
#  'test_6186.JPEG',
#  'test_951.JPEG',
#  'test_5497.JPEG',
#  'test_3447.JPEG',
#  'test_587.JPEG',
#  'test_5618.JPEG',
#  'test_6606.JPEG',
#  'test_1581.JPEG',
#  'test_608.JPEG',
#  'test_9642.JPEG',
#  'test_1462.JPEG',
#  'test_4140.JPEG',
#  'test_6298.JPEG',
#  'test_7960.JPEG',
#  'test_3394.JPEG',
#  'test_2776.JPEG',
#  'test_6921.JPEG',
#  'test_1676.JPEG',
#  'test_9378.JPEG',
#  'test_1014.JPEG',
#  'test_9334.JPEG',
#  'test_8980.JPEG',
#  'test_1923.JPEG',
#  'test_9396.JPEG',
#  'test_5944.JPEG',
#  'test_7941.JPEG',
#  'test_3882.JPEG',
#  'test_1849.JPEG',
#  'test_2221.JPEG',
#  'test_8999.JPEG',
#  'test_1019.JPEG',
#  'test_8344.JPEG',
#  'test_9943.JPEG',
#  'test_6624.JPEG',
#  'test_3279.JPEG',
#  'test_7399.JPEG',
#  'test_4010.JPEG',
#  'test_585.JPEG',
#  'test_1911.JPEG',
#  'test_4971.JPEG',
#  'test_405.JPEG',
#  'test_8765.JPEG',
#  'test_275.JPEG',
#  'test_7881.JPEG',
#  'test_688.JPEG',
#  'test_1666.JPEG',
#  'test_9744.JPEG',
#  'test_6412.JPEG',
#  'test_4821.JPEG',
#  'test_1451.JPEG',
#  'test_1746.JPEG',
#  'test_5967.JPEG',
#  'test_5871.JPEG',
#  'test_2295.JPEG',
#  'test_1163.JPEG',
#  'test_6766.JPEG',
#  'test_9694.JPEG',
#  'test_9935.JPEG',
#  'test_9891.JPEG',
#  'test_8251.JPEG',
#  'test_2774.JPEG',
#  'test_645.JPEG',
#  'test_2709.JPEG',
#  'test_142.JPEG',
#  'test_3964.JPEG',
#  'test_7872.JPEG',
#  'test_5428.JPEG',
#  'test_6115.JPEG',
#  'test_5671.JPEG',
#  'test_4465.JPEG',
#  'test_8660.JPEG',
#  'test_509.JPEG',
#  'test_9652.JPEG',
#  'test_2342.JPEG',
#  'test_703.JPEG',
#  'test_74.JPEG',
#  'test_8375.JPEG',
#  'test_7297.JPEG',
#  'test_4761.JPEG',
#  'test_8301.JPEG',
#  'test_7278.JPEG',
#  'test_4186.JPEG',
#  'test_7140.JPEG',
#  'test_9423.JPEG',
#  'test_371.JPEG',
#  'test_4890.JPEG',
#  'test_9843.JPEG',
#  'test_9487.JPEG',
#  'test_3976.JPEG',
#  'test_4082.JPEG',
#  'test_6070.JPEG',
#  'test_3409.JPEG',
#  'test_7221.JPEG',
#  'test_6476.JPEG',
#  'test_7948.JPEG',
#  'test_7534.JPEG',
#  'test_2341.JPEG',
#  'test_283.JPEG',
#  'test_4852.JPEG',
#  'test_6753.JPEG',
#  'test_169.JPEG',
#  'test_619.JPEG',
#  'test_3507.JPEG',
#  'test_7422.JPEG',
#  'test_3818.JPEG',
#  'test_6940.JPEG',
#  'test_7730.JPEG',
#  'test_578.JPEG',
#  'test_9728.JPEG',
#  'test_2801.JPEG',
#  'test_2881.JPEG',
#  'test_3981.JPEG',
#  'test_1505.JPEG',
#  'test_8153.JPEG',
#  'test_7637.JPEG',
#  'test_6484.JPEG',
#  'test_7749.JPEG',
#  'test_8421.JPEG',
#  'test_7670.JPEG',
#  'test_3528.JPEG',
#  'test_7365.JPEG',
#  'test_3971.JPEG',
#  'test_8205.JPEG',
#  'test_7842.JPEG',
#  'test_7495.JPEG',
#  'test_2468.JPEG',
#  'test_1042.JPEG',
#  'test_9046.JPEG',
#  'test_6602.JPEG',
#  'test_2051.JPEG',
#  'test_4459.JPEG',
#  'test_9631.JPEG',
#  'test_4777.JPEG',
#  'test_7100.JPEG',
#  'test_8340.JPEG',
#  'test_6944.JPEG',
#  'test_1594.JPEG',
#  'test_3804.JPEG',
#  'test_3333.JPEG',
#  'test_6683.JPEG',
#  'test_6149.JPEG',
#  'test_404.JPEG',
#  'test_2462.JPEG',
#  'test_1167.JPEG',
#  'test_3720.JPEG',
#  'test_2359.JPEG',
#  'test_9490.JPEG',
#  'test_8088.JPEG',
#  'test_2513.JPEG',
#  'test_6839.JPEG',
#  'test_1986.JPEG',
#  'test_7051.JPEG',
#  'test_8515.JPEG',
#  'test_617.JPEG',
#  'test_1873.JPEG',
#  'test_4782.JPEG',
#  'test_8968.JPEG',
#  'test_8758.JPEG',
#  'test_1041.JPEG',
#  'test_7019.JPEG',
#  'test_8008.JPEG',
#  'test_6304.JPEG',
#  'test_6137.JPEG',
#  'test_3251.JPEG',
#  'test_5812.JPEG',
#  'test_5160.JPEG',
#  'test_5235.JPEG',
#  'test_9039.JPEG',
#  'test_7509.JPEG',
#  'test_2837.JPEG',
#  'test_8570.JPEG',
#  'test_6621.JPEG',
#  'test_9101.JPEG',
#  'test_1694.JPEG',
#  'test_3587.JPEG',
#  'test_8349.JPEG',
#  'test_8456.JPEG',
#  'test_413.JPEG',
#  'test_2352.JPEG',
#  'test_901.JPEG',
#  'test_8442.JPEG',
#  'test_8537.JPEG',
#  'test_1458.JPEG',
#  'test_3047.JPEG',
#  'test_7273.JPEG',
#  'test_3036.JPEG',
#  'test_5103.JPEG',
#  'test_4309.JPEG',
#  'test_932.JPEG',
#  'test_601.JPEG',
#  'test_8422.JPEG',
#  'test_665.JPEG',
#  'test_804.JPEG',
#  'test_6375.JPEG',
#  'test_5803.JPEG',
#  'test_8965.JPEG',
#  'test_3173.JPEG',
#  'test_1181.JPEG',
#  'test_5882.JPEG',
#  'test_7113.JPEG',
#  'test_2404.JPEG',
#  'test_8377.JPEG',
#  'test_4989.JPEG',
#  'test_7282.JPEG',
#  'test_7618.JPEG',
#  'test_3483.JPEG',
#  'test_3557.JPEG',
#  'test_7795.JPEG',
#  'test_8944.JPEG',
#  'test_7990.JPEG',
#  'test_2791.JPEG',
#  'test_3472.JPEG',
#  'test_8775.JPEG',
#  'test_3454.JPEG',
#  'test_1043.JPEG',
#  'test_9397.JPEG',
#  'test_607.JPEG',
#  'test_8274.JPEG',
#  'test_9304.JPEG',
#  'test_5496.JPEG',
#  'test_9221.JPEG',
#  'test_5401.JPEG',
#  'test_3958.JPEG',
#  'test_5211.JPEG',
#  'test_2825.JPEG',
#  'test_9839.JPEG',
#  'test_9613.JPEG',
#  'test_87.JPEG',
#  'test_6384.JPEG',
#  'test_4687.JPEG',
#  'test_7198.JPEG',
#  'test_4755.JPEG',
#  'test_2457.JPEG',
#  'test_2679.JPEG',
#  'test_4336.JPEG',
#  'test_1773.JPEG',
#  'test_2265.JPEG',
#  'test_8956.JPEG',
#  'test_9822.JPEG',
#  'test_1994.JPEG',
#  'test_5297.JPEG',
#  'test_9343.JPEG',
#  'test_4625.JPEG',
#  'test_1040.JPEG',
#  'test_5802.JPEG',
#  'test_6287.JPEG',
#  'test_7627.JPEG',
#  'test_670.JPEG',
#  'test_1223.JPEG',
#  'test_6398.JPEG',
#  'test_2185.JPEG',
#  'test_5664.JPEG',
#  'test_9716.JPEG',
#  'test_5135.JPEG',
#  'test_4584.JPEG',
#  'test_6710.JPEG',
#  'test_8206.JPEG',
#  'test_6098.JPEG',
#  'test_8688.JPEG',
#  'test_7729.JPEG',
#  'test_3937.JPEG',
#  'test_2212.JPEG',
#  'test_1233.JPEG',
#  'test_4052.JPEG',
#  'test_3704.JPEG',
#  'test_171.JPEG',
#  'test_500.JPEG',
#  'test_7631.JPEG',
#  'test_3215.JPEG',
#  'test_2314.JPEG',
#  'test_2651.JPEG',
#  'test_1881.JPEG',
#  'test_889.JPEG',
#  'test_5386.JPEG',
#  'test_8611.JPEG',
#  'test_5622.JPEG',
#  'test_4444.JPEG',
#  'test_2622.JPEG',
#  'test_820.JPEG',
#  'test_9525.JPEG',
#  'test_164.JPEG',
#  'test_5306.JPEG',
#  'test_3499.JPEG',
#  'test_4342.JPEG',
#  'test_7699.JPEG',
#  'test_205.JPEG',
#  'test_4494.JPEG',
#  'test_883.JPEG',
#  'test_4865.JPEG',
#  'test_8183.JPEG',
#  'test_3238.JPEG',
#  'test_6642.JPEG',
#  'test_3607.JPEG',
#  'test_4401.JPEG',
#  'test_9647.JPEG',
#  'test_8899.JPEG',
#  'test_7373.JPEG',
#  'test_8136.JPEG',
#  'test_7910.JPEG',
#  'test_2637.JPEG',
#  'test_4296.JPEG',
#  'test_4184.JPEG',
#  'test_2027.JPEG',
#  'test_2074.JPEG',
#  'test_397.JPEG',
#  'test_5117.JPEG',
#  'test_3612.JPEG',
#  'test_8596.JPEG',
#  'test_3540.JPEG',
#  'test_60.JPEG',
#  'test_6707.JPEG',
#  'test_9979.JPEG',
#  'test_8554.JPEG',
#  'test_4750.JPEG',
#  'test_1739.JPEG',
#  'test_8929.JPEG',
#  'test_8974.JPEG',
#  'test_4771.JPEG',
#  'test_8518.JPEG',
#  'test_2223.JPEG',
#  'test_8100.JPEG',
#  'test_8224.JPEG',
#  'test_2748.JPEG',
#  'test_8723.JPEG',
#  'test_6560.JPEG',
#  'test_4228.JPEG',
#  'test_865.JPEG',
#  'test_9249.JPEG',
#  'test_2544.JPEG',
#  'test_3788.JPEG',
#  'test_6800.JPEG',
#  'test_4300.JPEG',
#  'test_5427.JPEG',
#  'test_7638.JPEG',
#  'test_3357.JPEG',
#  'test_9332.JPEG',
#  'test_5884.JPEG',
#  'test_4462.JPEG',
#  'test_1798.JPEG',
#  'test_5833.JPEG',
#  'test_5041.JPEG',
#  'test_1526.JPEG',
#  'test_4921.JPEG',
#  'test_4653.JPEG',
#  'test_1365.JPEG',
#  'test_4274.JPEG',
#  'test_3396.JPEG',
#  'test_1327.JPEG',
#  'test_111.JPEG',
#  'test_5114.JPEG',
#  'test_5638.JPEG',
#  'test_3782.JPEG',
#  'test_9271.JPEG',
#  'test_7255.JPEG',
#  'test_2197.JPEG',
#  'test_1427.JPEG',
#  'test_4503.JPEG',
#  'test_7636.JPEG',
#  'test_5417.JPEG',
#  'test_8229.JPEG',
#  'test_1521.JPEG',
#  'test_6912.JPEG',
#  'test_1906.JPEG',
#  'test_332.JPEG',
#  'test_4830.JPEG',
#  'test_2625.JPEG',
#  'test_4590.JPEG',
#  'test_2024.JPEG',
#  'test_6551.JPEG',
#  'test_7822.JPEG',
#  'test_2949.JPEG',
#  'test_1119.JPEG',
#  'test_9406.JPEG',
#  'test_4848.JPEG',
#  'test_3291.JPEG',
#  'test_4908.JPEG',
#  'test_699.JPEG',
#  'test_2019.JPEG',
#  'test_8264.JPEG',
#  'test_7610.JPEG',
#  'test_7549.JPEG',
#  ...]

# %%
model.save('22_model.h5')
# Out:
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
for i in lst:
    img = plt.imread('../Dataset/imagenet/test/images/'+ i)
    if len(img.shape) == 3:
        img = img/ 255
        img = img.reshape(1, 64, 64, 3)
        pred = model.predict(img, verbose= False)
        pred = np.argmax(pred)
        if pred == 1:
            print(i)
            # img = img.reshape(64, 64, 3)
            # plt.imshow(img)
# Out:
# test_9685.JPEG
# test_6696.JPEG
# test_3754.JPEG
# test_3811.JPEG
# test_6307.JPEG
# test_1656.JPEG
# test_7939.JPEG
# test_230.JPEG
# test_1733.JPEG
# test_871.JPEG
# test_7771.JPEG
# test_1729.JPEG
# test_1052.JPEG
# test_499.JPEG
# test_7027.JPEG
# test_3364.JPEG
# test_494.JPEG
# test_4427.JPEG
# test_1483.JPEG
# test_7790.JPEG
# test_5292.JPEG
# test_4972.JPEG
# test_6708.JPEG
# test_6495.JPEG
# test_458.JPEG
# test_672.JPEG
# test_3735.JPEG
# test_951.JPEG
# test_9378.JPEG
# test_4821.JPEG
# test_6766.JPEG
# test_3976.JPEG
# test_9490.JPEG
# test_1986.JPEG
# test_8515.JPEG
# test_5803.JPEG
# test_2404.JPEG
# test_3483.JPEG
# test_1773.JPEG
# test_500.JPEG
# test_889.JPEG
# test_205.JPEG
# test_2637.JPEG
# test_4750.JPEG
# test_6560.JPEG
# test_1450.JPEG
# test_7858.JPEG
# test_3865.JPEG
# test_1168.JPEG
# test_2807.JPEG
# test_2765.JPEG
# test_6866.JPEG
# test_2803.JPEG
# test_7280.JPEG
# test_3687.JPEG
# test_9143.JPEG
# test_952.JPEG
# test_4811.JPEG
# test_9882.JPEG
# test_4396.JPEG
# test_1122.JPEG
# test_6992.JPEG
# test_8467.JPEG
# test_6767.JPEG
# test_8784.JPEG
# test_3879.JPEG
# test_9045.JPEG
# test_2029.JPEG
# test_8236.JPEG
# test_2912.JPEG
# test_2194.JPEG
# test_6806.JPEG
# test_6562.JPEG
# test_3104.JPEG
# test_147.JPEG
# test_2006.JPEG
# test_1681.JPEG
# test_6688.JPEG
# test_5083.JPEG
# test_4844.JPEG
# test_9025.JPEG
# test_6948.JPEG
# test_5888.JPEG
# test_7379.JPEG
# test_2890.JPEG
# test_9217.JPEG
# test_8665.JPEG
# test_2636.JPEG
# test_1559.JPEG
# test_7689.JPEG
# test_7953.JPEG
# test_3960.JPEG
# test_6292.JPEG
# test_5058.JPEG
# test_2901.JPEG
# test_6102.JPEG
# test_2365.JPEG
# test_9665.JPEG
# test_4815.JPEG
# test_7679.JPEG
# test_4128.JPEG
# test_2859.JPEG
# test_9697.JPEG
# test_1081.JPEG
# test_5574.JPEG
# test_5866.JPEG
# test_3719.JPEG
# test_532.JPEG
# test_4517.JPEG
# test_6002.JPEG
# test_9780.JPEG
# test_7174.JPEG
# test_3480.JPEG
# test_7861.JPEG
# test_2280.JPEG
# test_8608.JPEG
# test_6103.JPEG
# test_4714.JPEG
# test_6823.JPEG
# test_4564.JPEG
# test_4354.JPEG
# test_7177.JPEG
# test_2100.JPEG
# test_8679.JPEG
# test_9668.JPEG
# test_7908.JPEG
# test_3323.JPEG
# test_9521.JPEG
# test_1574.JPEG
# test_4542.JPEG
# test_6901.JPEG
# test_7705.JPEG
# test_295.JPEG
# test_7469.JPEG
# test_9555.JPEG
# test_8728.JPEG
# test_9020.JPEG
# test_3841.JPEG
# test_1424.JPEG
# test_5336.JPEG
# test_4562.JPEG
# test_564.JPEG
# test_1603.JPEG
# test_2226.JPEG
# test_8800.JPEG
# test_4931.JPEG
# test_8573.JPEG
# test_6640.JPEG
# test_5369.JPEG
# test_6505.JPEG
# test_2306.JPEG
# test_5056.JPEG
# test_337.JPEG
# test_3435.JPEG
# test_1856.JPEG
# test_3228.JPEG
# test_6999.JPEG
# test_9916.JPEG
# test_6702.JPEG
# test_9205.JPEG
# test_4514.JPEG
# test_7303.JPEG
# test_1454.JPEG
# test_1863.JPEG
# test_8711.JPEG
# test_5779.JPEG
# test_4556.JPEG
# test_6185.JPEG
# test_7120.JPEG
# test_6927.JPEG
# test_3024.JPEG
# test_8670.JPEG
# test_4602.JPEG
# test_2987.JPEG
# test_8281.JPEG
# test_8089.JPEG
# test_2908.JPEG
# test_3133.JPEG
# test_8869.JPEG
# test_2523.JPEG
# test_3903.JPEG
# test_3137.JPEG
# test_1665.JPEG
# test_5475.JPEG
# test_6305.JPEG
# test_1414.JPEG
# test_4984.JPEG
# test_6660.JPEG
# test_2851.JPEG
# test_8406.JPEG
# test_6493.JPEG
# test_6151.JPEG
# test_9709.JPEG
# test_4475.JPEG
# test_3111.JPEG
# test_1947.JPEG
# test_2770.JPEG
# test_2932.JPEG
# test_4586.JPEG
# test_1684.JPEG
# test_8908.JPEG
# test_206.JPEG
# test_8513.JPEG
# test_1861.JPEG
# test_386.JPEG
# test_9464.JPEG
# test_3468.JPEG
# test_6027.JPEG
# test_1391.JPEG
# test_8134.JPEG
# test_5667.JPEG
# test_7188.JPEG
# test_5522.JPEG
# test_9387.JPEG
# test_6951.JPEG
# test_4290.JPEG
# test_4837.JPEG
# test_3796.JPEG
# test_8278.JPEG
# test_2543.JPEG
# test_1047.JPEG
# test_644.JPEG
# test_1964.JPEG
# test_5651.JPEG
# test_1781.JPEG
# test_3627.JPEG
# test_9667.JPEG
# test_1709.JPEG
# test_3530.JPEG
# test_809.JPEG
# test_4269.JPEG
# test_5285.JPEG
# test_8045.JPEG
# test_4877.JPEG
# test_7241.JPEG
# test_3273.JPEG
# test_3044.JPEG
# test_3412.JPEG
# test_9680.JPEG
# test_3312.JPEG
# test_2664.JPEG
# test_3067.JPEG
# test_709.JPEG
# test_1178.JPEG
# test_1273.JPEG
# test_2459.JPEG
# test_4655.JPEG
# test_4251.JPEG
# test_516.JPEG
# test_6886.JPEG
# test_9890.JPEG
# test_6487.JPEG
# test_1648.JPEG
# test_529.JPEG
# test_3125.JPEG
# test_6407.JPEG
# test_1053.JPEG
# test_3113.JPEG
# test_4757.JPEG
# test_1048.JPEG
# test_2959.JPEG
# test_6388.JPEG
# test_3826.JPEG
# test_4760.JPEG
# test_2302.JPEG
# test_4293.JPEG
# test_5973.JPEG
# test_1008.JPEG
# test_8633.JPEG
# test_7417.JPEG
# test_2526.JPEG
# test_1231.JPEG
# test_2919.JPEG
# test_9725.JPEG
# test_3798.JPEG
# test_1478.JPEG
# test_1854.JPEG
# test_6223.JPEG
# test_7427.JPEG
# test_9203.JPEG
# test_3276.JPEG
# test_8840.JPEG
# test_8384.JPEG
# test_2608.JPEG
# test_5918.JPEG
# test_1879.JPEG
# test_2362.JPEG
# test_8480.JPEG
# test_8836.JPEG
# test_7498.JPEG
# test_4635.JPEG
# test_8580.JPEG
# test_8787.JPEG
# test_4387.JPEG
# test_6735.JPEG
# test_9073.JPEG
# test_1457.JPEG
# test_7880.JPEG
# test_8695.JPEG
# test_6774.JPEG
# test_5093.JPEG
# test_6189.JPEG
# test_7042.JPEG
# test_3819.JPEG
# test_6913.JPEG
# test_5341.JPEG
# test_3120.JPEG
# test_7752.JPEG
# test_1309.JPEG
# test_9435.JPEG
# test_1659.JPEG
# test_6297.JPEG
# test_505.JPEG
# test_5978.JPEG
# test_5845.JPEG
# test_1320.JPEG
# test_1265.JPEG
# test_6220.JPEG
# test_2279.JPEG
# test_2485.JPEG
# test_208.JPEG
# test_8262.JPEG
# test_5629.JPEG
# test_5181.JPEG
# test_8993.JPEG
# test_8289.JPEG
# test_9199.JPEG
# test_1744.JPEG
# test_3202.JPEG
# test_4467.JPEG
# test_4606.JPEG
# test_850.JPEG
# test_588.JPEG
# test_3615.JPEG
# test_9174.JPEG
# test_7196.JPEG
# test_2674.JPEG
# test_5349.JPEG
# test_214.JPEG
# test_9461.JPEG
# test_7737.JPEG
# test_5310.JPEG
# test_4009.JPEG
# test_1237.JPEG
# test_9357.JPEG
# test_1970.JPEG
# test_2977.JPEG
# test_3838.JPEG
# test_7747.JPEG
# test_5773.JPEG
# test_7157.JPEG
# test_539.JPEG
# test_3895.JPEG
# test_2923.JPEG
# test_722.JPEG
# test_5233.JPEG
# test_9977.JPEG
# test_6989.JPEG
# test_9211.JPEG
# test_5682.JPEG
# test_1580.JPEG
# test_1346.JPEG
# test_349.JPEG
# test_1046.JPEG
# test_9201.JPEG
# test_9287.JPEG
# test_8921.JPEG
# test_8339.JPEG
# test_8346.JPEG
# test_1834.JPEG
# test_9079.JPEG
# test_3087.JPEG
# test_6980.JPEG
# test_3256.JPEG
# test_5728.JPEG
# test_288.JPEG
# test_1915.JPEG
# test_7578.JPEG
# test_8966.JPEG
# test_4420.JPEG
# test_1801.JPEG
# test_1557.JPEG
# test_8538.JPEG
# test_635.JPEG
# test_3803.JPEG
# test_2378.JPEG
# test_1766.JPEG
# test_3050.JPEG
# test_394.JPEG
# test_7059.JPEG
# test_1266.JPEG
# test_1431.JPEG
# test_549.JPEG
# test_7961.JPEG
# test_3018.JPEG
# test_8271.JPEG
# test_733.JPEG
# test_4975.JPEG
# test_4370.JPEG
# test_7926.JPEG
# test_3320.JPEG
# test_2772.JPEG
# test_8439.JPEG
# test_5250.JPEG
# test_6253.JPEG
# test_948.JPEG
# test_775.JPEG
# test_3437.JPEG
# test_4155.JPEG
# test_6096.JPEG
# test_6574.JPEG
# test_6051.JPEG
# test_8529.JPEG
# test_1238.JPEG
# test_7587.JPEG
# test_6841.JPEG
# test_7046.JPEG
# test_9160.JPEG
# test_5946.JPEG
# test_9036.JPEG
# test_3331.JPEG
# test_5396.JPEG
# test_5337.JPEG
# test_3927.JPEG
# test_6471.JPEG
# test_7898.JPEG
# test_2023.JPEG
# test_6957.JPEG
# test_2287.JPEG
# test_6488.JPEG
# test_3358.JPEG
# test_840.JPEG
# test_4087.JPEG
# test_8884.JPEG
# test_4661.JPEG
# test_6159.JPEG
# test_8425.JPEG
# test_9611.JPEG
# test_7968.JPEG
# test_631.JPEG
# test_3583.JPEG
# test_5374.JPEG
# test_7596.JPEG
# test_345.JPEG
# test_1471.JPEG
# test_1668.JPEG
# test_8085.JPEG
# test_2089.JPEG
# test_8059.JPEG
# test_9752.JPEG
# test_4557.JPEG
# test_8420.JPEG
# test_7359.JPEG
# test_1837.JPEG
# test_8145.JPEG
# test_4005.JPEG
# test_621.JPEG
# test_1324.JPEG
# test_2652.JPEG
# test_6072.JPEG
# test_6888.JPEG
# test_4389.JPEG
# test_3439.JPEG
# test_417.JPEG
# test_7980.JPEG
# test_6797.JPEG
# test_9970.JPEG
# test_4802.JPEG
# test_8702.JPEG
# test_3266.JPEG
# test_2728.JPEG
# test_9450.JPEG
# test_5796.JPEG
# test_4788.JPEG
# test_302.JPEG
# test_3726.JPEG
# test_3525.JPEG
# test_7667.JPEG
# test_6982.JPEG
# test_3390.JPEG
# test_3861.JPEG
# test_9057.JPEG
# test_6182.JPEG
# test_7551.JPEG
# test_1222.JPEG
# test_4712.JPEG
# test_6123.JPEG
# test_3095.JPEG
# test_1690.JPEG
# test_2155.JPEG
# test_3741.JPEG
# test_9720.JPEG
# test_3595.JPEG
# test_344.JPEG
# test_9335.JPEG
# test_2273.JPEG
# test_9267.JPEG
